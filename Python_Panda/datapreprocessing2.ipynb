# %%
import pandas as pd

# %%
titleslesslessdf = pd.read_csv(r"C:\Users\tyto4\OneDrive\Dokumente\0_Winfo_MA\SS22_IR\IR_Netflix_TVShows_Movies_VAD\Data\AufbereiteteDaten\titleslesslessdf.csv", index_col=False)

# %%
titleslesslessdf.reset_index(drop=True,inplace=True)

# %%
titleslesslessdf
# Out:
#              id                               title   type  release_year  \
# 0       tm84618                         Taxi Driver  MOVIE          1976
# 1      tm127384     Monty Python and the Holy Grail  MOVIE          1975
# 2       tm70993                       Life of Brian  MOVIE          1979
# 3      tm190788                        The Exorcist  MOVIE          1973
# 4       ts22164        Monty Python's Flying Circus   SHOW          1969
# ...         ...                                 ...    ...           ...
# 5036  tm1097142                            My Bride  MOVIE          2021
# 5037   tm878575                 The Heartbreak Club  MOVIE          2021
# 5038   ts286386                         The Big Day   SHOW          2021
# 5039  tm1004011                       Time to Dance  MOVIE          2021
# 5040   ts271048  Mighty Little Bheem: Kite Festival   SHOW          2021
#
#       runtime                             genres  seasons  imdb_score  \
# ...

# %%
# del titleslesslessdf["Unnamed: 0"]

# %%
moviedf = titleslesslessdf[titleslesslessdf["type"] == "MOVIE"]

# %%
showdf = titleslesslessdf[titleslesslessdf["type"] == "SHOW"]

# %%
showdf
# Out:
#             id                               title  type  release_year  \
# 4      ts22164        Monty Python's Flying Circus  SHOW          1969
# 28     ts45948    Monty Python's Fliegender Zirkus  SHOW          1972
# 43     ts20681                            Seinfeld  SHOW          1989
# 51     ts22082                        Knight Rider  SHOW          1982
# 53     ts21715                    Thomas & Friends  SHOW          1984
# ...        ...                                 ...   ...           ...
# 5018  ts309235                      Christmas Flow  SHOW          2021
# 5020  ts307816         Korean Cold Noodle Rhapsody  SHOW          2021
# 5029  ts273317                       Pitta Kathalu  SHOW          2021
# 5038  ts286386                         The Big Day  SHOW          2021
# 5040  ts271048  Mighty Little Bheem: Kite Festival  SHOW          2021
#
#       runtime                                             genres  seasons  \
# ...

# %%
moviedf.to_csv(r"C:\Users\tyto4\OneDrive\Dokumente\0_Winfo_MA\SS22_IR\IR_Netflix_TVShows_Movies_VAD\Data\AufbereiteteDaten\moviedf.csv",sep=",",index=False)
showdf.to_csv(r"C:\Users\tyto4\OneDrive\Dokumente\0_Winfo_MA\SS22_IR\IR_Netflix_TVShows_Movies_VAD\Data\AufbereiteteDaten\showdf.csv",sep=",",index=False)
