# %%
import pandas as pd

# %%
titlesdfless = pd.read_csv(r"C:\Users\tyto4\OneDrive\Dokumente\0_Winfo_MA\SS22_IR\IR_Netflix_TVShows_Movies_VAD\Data\AufbereiteteDaten\titleslessdf.csv", sep=',')

# %%
titlesdfless
# Out:
#       Unnamed: 0         id                                title   type  \
# 0              0   ts300399  Five Came Back: The Reference Films   SHOW
# 1              1    tm84618                          Taxi Driver  MOVIE
# 2              2   tm127384      Monty Python and the Holy Grail  MOVIE
# 3              3    tm70993                        Life of Brian  MOVIE
# 4              4   tm190788                         The Exorcist  MOVIE
# ...          ...        ...                                  ...    ...
# 5801        5801  tm1014599                            Fine Wine  MOVIE
# 5802        5802  tm1108171                       Edis Starlight  MOVIE
# 5803        5803  tm1045018                                Clash  MOVIE
# 5804        5804  tm1098060                       Shadow Parties  MOVIE
# 5805        5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year  runtime                             genres  \
# ...

# %%
titlesdfless=titlesdfless.dropna(subset=["id","title","type","release_year","runtime","imdb_score","imdb_votes"])

# %%
titlesdfless.to_csv(r"C:\Users\tyto4\OneDrive\Dokumente\0_Winfo_MA\SS22_IR\IR_Netflix_TVShows_Movies_VAD\Data\AufbereiteteDaten\titleslessdf1.csv",sep=",")
