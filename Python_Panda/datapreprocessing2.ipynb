# %%
import pandas as pd

# %%
titleslesslessdf = pd.read_csv(r"C:\Users\tyto4\OneDrive\Dokumente\0_Winfo_MA\SS22_IR\IR_Netflix_TVShows_Movies_VAD\Data\AufbereiteteDaten\titleslesslessdf.csv", sep=',',index_col=False)

# %%
titleslesslessdf
# Out:
#       Unnamed: 0         id                               title   type  \
# 0              1    tm84618                         Taxi Driver  MOVIE
# 1              2   tm127384     Monty Python and the Holy Grail  MOVIE
# 2              3    tm70993                       Life of Brian  MOVIE
# 3              4   tm190788                        The Exorcist  MOVIE
# 4              5    ts22164        Monty Python's Flying Circus   SHOW
# ...          ...        ...                                 ...    ...
# 5036        5792  tm1097142                            My Bride  MOVIE
# 5037        5795   tm878575                 The Heartbreak Club  MOVIE
# 5038        5796   ts286386                         The Big Day   SHOW
# 5039        5798  tm1004011                       Time to Dance  MOVIE
# 5040        5805   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year  runtime  imdb_score  imdb_votes  tmdb_popularity  \
# ...

# %%
moviedf = titleslesslessdf[titleslesslessdf["type"] == "MOVIE"]

# %%
showdf = titleslesslessdf[titleslesslessdf["type"] == "SHOW"]

# %%
showdf
# Out:
#       Unnamed: 0        id                               title  type  \
# 4              5   ts22164        Monty Python's Flying Circus  SHOW
# 28            29   ts45948    Monty Python's Fliegender Zirkus  SHOW
# 43            47   ts20681                            Seinfeld  SHOW
# 51            55   ts22082                        Knight Rider  SHOW
# 53            57   ts21715                    Thomas & Friends  SHOW
# ...          ...       ...                                 ...   ...
# 5018        5768  ts309235                      Christmas Flow  SHOW
# 5020        5770  ts307816         Korean Cold Noodle Rhapsody  SHOW
# 5029        5785  ts273317                       Pitta Kathalu  SHOW
# 5038        5796  ts286386                         The Big Day  SHOW
# 5040        5805  ts271048  Mighty Little Bheem: Kite Festival  SHOW
#
#       release_year  runtime  imdb_score  imdb_votes  tmdb_popularity  \
# ...

# %%
moviedf.to_csv(r"C:\Users\tyto4\OneDrive\Dokumente\0_Winfo_MA\SS22_IR\IR_Netflix_TVShows_Movies_VAD\Data\AufbereiteteDaten\moviedf.csv",sep=",")
showdf.to_csv(r"C:\Users\tyto4\OneDrive\Dokumente\0_Winfo_MA\SS22_IR\IR_Netflix_TVShows_Movies_VAD\Data\AufbereiteteDaten\showdf.csv",sep=",")
